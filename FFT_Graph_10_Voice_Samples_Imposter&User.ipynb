# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import IPython.display as ipd
import librosa
import librosa.display
import scipy

# %%
#AJ's Voice Samples
AJ1="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (1).wav"
AJ2="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (2).wav"
AJ3="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (3).wav"
AJ4="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (4).wav"
AJ5="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (5).wav"
AJ6="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (6).wav"
AJ7="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (7).wav"
AJ8="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (8).wav"
AJ9="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (9).wav"
AJ10="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (10).wav"

# %%
#AJ's - Separate graphs of all samples
audio_list = {AJ1, AJ2, AJ3, AJ4, AJ5, AJ6, AJ7, AJ8, AJ9, AJ10}
for audio in audio_list:
    plt.figure(figsize=(14,5))
    data,sample_rate=librosa.load(audio)
    librosa.display.waveplot(data,sr=sample_rate)
    ipd.Audio(audio)

# %%
#AJ's - combined graph of all samples
pathAudio = "C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/"
files = librosa.util.find_files(pathAudio, ext=['wav']) 
files = np.asarray(files)
for y in files: 
    data = librosa.load(y,mono = True)   
    data = data[0]     
    librosa.display.waveplot(data)

# %%
#Imposter's Voice Samples
I1="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (1).wav"
I2="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (2).wav"
I3="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (3).wav"
I4="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (4).wav"
I5="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (5).wav"
I6="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (6).wav"
I7="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (7).wav"
I8="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (8).wav"
I9="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (9).wav"
I10="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (10).wav"

# %%
#Imposter's - combined graph of all samples
pathAudio = "C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/"
files = librosa.util.find_files(pathAudio, ext=['wav']) 
files = np.asarray(files)
for y in files: 
    data = librosa.load(y,mono = True)   
    data = data[0]     
    librosa.display.waveplot(data)

# %%
#Imposter's - Separate graphs of all samples
audio_list = {I1, I2, I3, I4, I5, I6, I7, I8, I9, I10}
for audio in audio_list:
    plt.figure(figsize=(14,5))
    data,sample_rate=librosa.load(audio)
    librosa.display.waveplot(data,sr=sample_rate)
    ipd.Audio(audio)

# %%
#FFT for AJ's voice samples
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
def plot(data):
    plt.plot(data, color='steelblue')
    plt.figure()
    plt.show()
    
AJ1="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (1).wav"
AJ2="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (2).wav"
AJ3="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (3).wav"
AJ4="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (4).wav"
AJ5="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (5).wav"
AJ6="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (6).wav"
AJ7="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (7).wav"
AJ8="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (8).wav"
AJ9="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (9).wav"
AJ10="C:/Users/Ajinkya/Downloads/Voice Authentication Project/AJ/AJ (10).wav"

audio_list = {AJ1, AJ2, AJ3, AJ4, AJ5, AJ6, AJ7, AJ8, AJ9, AJ10}
for audio in audio_list:
    rate, wav_data = wavfile.read(audio)
    plot(wav_data)
    plot(np.abs(np.fft.fft(wav_data)))

# %%
#FFT for Imposter's voice samples
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
def plot(data):
    plt.plot(data, color='steelblue')
    plt.figure()
    plt.show()
    
I1="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (1).wav"
I2="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (2).wav"
I3="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (3).wav"
I4="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (4).wav"
I5="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (5).wav"
I6="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (6).wav"
I7="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (7).wav"
I8="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (8).wav"
I9="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (9).wav"
I10="C:/Users/Ajinkya/Downloads/Voice Authentication Project/Imposter/Imposter (10).wav"

audio_list = {I1, I2, I3, I4, I5, I6, I7, I8, I9, I10}
for audio in audio_list:
    rate, wav_data = wavfile.read(audio)
    plot(wav_data)
    plot(np.abs(np.fft.fft(wav_data)))
